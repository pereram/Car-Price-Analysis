# %% [markdown]
# <a href="https://colab.research.google.com/github/pereram/Car-Price-Analysis/blob/main/pyspark_car_price_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import SparkSession
from pyspark.sql import SparkSession
from pyspark.sql.functions import count, when, col

# Create SparkSession
spark = SparkSession.builder \
      .master("local[1]") \
      .appName("SparkByExamples.com") \
      .getOrCreate()

# %%
# read the csv file and load into a data frame.
df = spark.read.csv("/content/Car_price_cleaned.csv",header=True, inferSchema=True)




# Display schema and data
df.printSchema()
df.show(5)
# Out:
# root
#  |-- car_ID: integer (nullable = true)
#  |-- symboling: integer (nullable = true)
#  |-- CarName: string (nullable = true)
#  |-- fueltype: integer (nullable = true)
#  |-- aspiration: integer (nullable = true)
#  |-- doornumber: integer (nullable = true)
#  |-- carbody: integer (nullable = true)
#  |-- drivewheel: integer (nullable = true)
#  |-- enginelocation: integer (nullable = true)
#  |-- wheelbase: double (nullable = true)
#  |-- carlength: double (nullable = true)
#  |-- carwidth: double (nullable = true)
#  |-- carheight: double (nullable = true)
#  |-- curbweight: double (nullable = true)
#  |-- enginetype: integer (nullable = true)
#  |-- cylindernumber: integer (nullable = true)
#  |-- enginesize: double (nullable = true)
#  |-- fuelsystem: integer (nullable = true)
#  |-- boreratio: double (nullable = true)
#  |-- stroke: double (nullable = true)
#  |-- compressionratio: double (nullable = true)
#  |-- horsepower: double (nullable = true)
# ...

# %%
df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df.columns]).show()
# Out:
# +------+---------+-------+--------+----------+----------+-------+----------+--------------+---------+---------+--------+---------+----------+----------+--------------+----------+----------+---------+------+----------------+----------+-------+-------+----------+-----+-----+-----+---------------------+-----------------+-----------------+----------------+-----------------+------------------+------------------+-----------------+--------------+------------------------+------------------+---------------+---------------+------------------+--------------+
# ...

# %%
df.describe().show()
# Out:
# +-------+-----------------+------------------+------------+-------------------+-------------------+-------------------+------------------+-----------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+------------------+--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+-----------------+------------------+---------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------------+------------------+-------------------+------------------+------------------+------------------+
# ...
